# %% [markdown]
# # Sample Notebook
#
# A small notebook demonstrating **markdown**, code, and outputs.

# %%
greeting = "hello from sucher"
print(greeting)
# Out:
# hello from sucher

# %%
import matplotlib.pyplot as plt
plt.plot([0, 1, 2], [0, 1, 4])
plt.show()
